# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import re
import json

# .env 파일에서 환경 변수 로드
load_dotenv()

def search_shop(key='한글'):
# 환경 변수에서 값 읽기
    client_id = os.getenv("NAVER_CLIENT_ID")
    client_secret = os.getenv("NAVER_CLIENT_SECRET")

    headers = {
        'X-Naver-Client-Id': client_id,
        'X-Naver-Client-Secret': client_secret,
    }

    payload = {
        'query': key,
        'display': 50,
        'sort': 'date'
    }

    url = 'https://openapi.naver.com/v1/search/shop.json'

    # 요청 보내기
    res = requests.get(url, params=payload, headers=headers)
    items_data = res.json()['items']

    # 결과 저장 리스트
    items_list = list()
    item_list = []


    for i, item in enumerate(items_data):
        title = re.sub(r'<.*?>', '', item['title'])

        item_list.append(title)
        item_list.append(item['link'])
        item_list.append(item['image'])
        item_list.append(item['lprice'])
        item_list.append(item['hprice'])
        item_list.append(item['productId'])
        item_list.append(item['productType'])
        item_list.append(item['brand'])
        item_list.append(item['maker'])
        item_list.append(item['category1'])
        item_list.append(item['category2'])
        item_list.append(item['category3'])
        item_list.append(item['category4'])  
        item_list.append(item['mallName'])      
        items_list.append(item_list)
        item_list = [] 

    df = pd.DataFrame(
        items_list,
        columns=["title", "link", "image", "lprice", "hprice", "productId", "productType", "brand", "maker","category1","category2","category3","category4","mallName"]
    )

    df.to_json('data/shop.json', orient='records', force_ascii=False, indent=2)

    # 불러오기
    shop_df = pd.read_json('data/shop.json')
        # 출력

    return shop_df


df = search_shop('가디건')

result = (
     df[df['lprice'] <= 50000]  # 조건
    .loc[:, ['brand', 'lprice', 'mallName', 'link']]  # 컬럼 선택
    .sort_values(by='lprice', ascending=True)  
    .reset_index(drop=True)  #
)
print(result)
# Out:
#    brand  lprice   mallName                                               link
# 0          16000      하이101  https://smartstore.naver.com/main/products/117...
# 1          16100       더펠리체  https://smartstore.naver.com/main/products/117...
# 2          16800      하이101  https://smartstore.naver.com/main/products/117...
# 3          17000       아고23  https://smartstore.naver.com/main/products/117...
# 4          17600      하이101  https://smartstore.naver.com/main/products/117...
# 5          18890     엠에스엠에잇  https://smartstore.naver.com/main/products/117...
# 6          20000       아고23  https://smartstore.naver.com/main/products/117...
# 7          20270   길정물삽십칠번지  https://smartstore.naver.com/main/products/117...
# 8          20800      하이101  https://smartstore.naver.com/main/products/117...
# 9          21000       아고23  https://smartstore.naver.com/main/products/117...
# 10         22400      하이101  https://smartstore.naver.com/main/products/117...
# 11    카라   23400   JUNSTORY  https://smartstore.naver.com/main/products/117...
# 12         24000      하이101  https://smartstore.naver.com/main/products/117...
# 13         24000       아고23  https://smartstore.naver.com/main/products/117...
# 14         24000       아고23  https://smartstore.naver.com/main/products/117...
# 15         25600      하이101  https://smartstore.naver.com/main/products/117...
# 16         26600       문베리아  https://smartstore.naver.com/main/products/117...
# 17         27000       아고23  https://smartstore.naver.com/main/products/117...
# 18         27500        유즈럽  https://smartstore.naver.com/main/products/117...
# 19         28000       아고23  https://smartstore.naver.com/main/products/117...
# 20         28000       아고23  https://smartstore.naver.com/main/products/117...
# 21         28800      하이101  https://smartstore.naver.com/main/products/117...
# 22         30100       문베리아  https://smartstore.naver.com/main/products/117...
# 23         30400      하이101  https://smartstore.naver.com/main/products/117...
# 24         31140        츄즈원  https://smartstore.naver.com/main/products/117...
# 25         32000      메이크샤인  https://smartstore.naver.com/main/products/117...
# 26         33000       아고23  https://smartstore.naver.com/main/products/117...
# 27         33000       아고23  https://smartstore.naver.com/main/products/117...
# 28   H&M   34840      OC-마켓  https://smartstore.naver.com/main/products/117...
# 29         35300       문베리아  https://smartstore.naver.com/main/products/117...
# 30         35910     바잉더프라임  https://smartstore.naver.com/main/products/117...
# 31         36000        린다유  https://smartstore.naver.com/main/products/117...
# 32         36000       아고23  https://smartstore.naver.com/main/products/117...
# 33         36000       아고23  https://smartstore.naver.com/main/products/117...
# 34  슈슈샤샤   36800      이끌림모드  https://smartstore.naver.com/main/products/117...
# 35  슈슈샤샤   36800      공주들마켓  https://smartstore.naver.com/main/products/117...
# 36         38000       아고23  https://smartstore.naver.com/main/products/117...
# 37         38000       아고23  https://smartstore.naver.com/main/products/117...
# 38         38600     좋은날-마켓  https://smartstore.naver.com/main/products/117...
# 39         40000       아고23  https://smartstore.naver.com/main/products/117...
# 40   무자크   40700   JUNSTORY  https://smartstore.naver.com/main/products/117...
# 41         41600      하이101  https://smartstore.naver.com/main/products/117...
# 42         43200      하이101  https://smartstore.naver.com/main/products/117...
# 43         44000       아고23  https://smartstore.naver.com/main/products/117...
# 44         44480  다모아 추천 상점  https://smartstore.naver.com/main/products/117...
# 45         48000       아고23  https://smartstore.naver.com/main/products/117...
# 46         48000       아고23  https://smartstore.naver.com/main/products/117...
